# %% [markdown]
# #Gráficos con PlotLy

# %%
# !pip install plotly==2.5.1

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls

tls.set_credentials_file(username = 'javilledo', api_key = 'VJYRyVaWzxF7X4SVNaha')

# %% [markdown]
# #Scatter Plots sencillos

# %%
import numpy as np
N = 2000
random_x = np.random.randn(N)
random_y = np.random.randn(N)

# %%
trace = go.Scatter(x = random_x, y = random_y, mode = 'markers')
py.plot([trace], filename = 'basic-scatter')
# Out:
# 'https://chart-studio.plotly.com/~javilledo/36'

# %%
plot_url = py.plot([trace], filename = 'basic-scatter-inline')
plot_url
# Out:
# 'https://chart-studio.plotly.com/~javilledo/38'

# %% [markdown]
# #Gráficos combinados

# %%
N = 200
rand_x = np.linspace(0, 1, N)
rand_y0 = np.random.randn(N) + 3
rand_y1 = np.random.randn(N)
rand_y2 = np.random.randn(N) - 3

# %%
trace0 = go.Scatter(x = rand_x, y = rand_y0, mode = 'markers',       name = 'Puntos')
trace1 = go.Scatter(x = rand_x, y = rand_y1, mode = 'lines',         name = 'Líneas')
trace2 = go.Scatter(x = rand_x, y = rand_y2, mode = 'lines+markers', name = 'Puntos y lineas')
data = [trace0, trace1, trace2]
py.plot(data, filename = 'scatter-line-plot')
# Out:
# 'https://chart-studio.plotly.com/~javilledo/40'

# %% [markdown]
# #Estilizado de gráficos

# %%
trace = go.Scatter(x = random_x, y = random_y, name = 'Puntos de estilo guay', mode = 'markers', marker = dict(size = 8, color = 'rgba(10,80,220, 0.8)', line = dict(width = 1, color = 'rgb(10, 10, 80)')))
layout = dict(title = 'Scatter Plot Estilizado', xaxis = dict(zeroline = False), yaxis = dict(zeroline = False))
fig = dict(data = [trace], layout = layout)
py.plot(fig)
# Out:
# 'https://chart-studio.plotly.com/~javilledo/72'

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
from plotly.offline import init_notebook_mode
test = plotly.offline.plot(fig, filename = 'testing.html')
test
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 'file:///content/testing.html'

# %%
trace = go.Histogram(x = random_x, name = 'Puntos de estilo guay')
layout = dict(title = 'Scatter Plot Estilizado', xaxis = dict(zeroline = False), yaxis = dict(zeroline = False))
fig = dict(data = [trace], layout = layout)
py.plot(fig)
# Out:
# 'https://chart-studio.plotly.com/~javilledo/74'

# %%
trace = go.Box(x = random_x, name = 'Puntos de estilo guay', fillcolor = 'rgba(180, 25, 95, 0.6)')
layout = dict(title = 'Scatter Plot Estilizado', xaxis = dict(zeroline = False), yaxis = dict(zeroline = False))
fig = dict(data = [trace], layout = layout)
py.plot(fig)
# Out:
# 'https://chart-studio.plotly.com/~javilledo/78'

# %% [markdown]
# #Información al hacer hover

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/javilledo/python-ml-course/master/datasets/usa-population/usa_states_population.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
N = data.shape[0]+1
c = ['hsl(' + str(h) + ',50%, 50%)' for h in np.linspace(0, 360, N)]

# %%
l = []
y = []
for i in range(int(N)):
  y.append((2000+ i ))
  trace0 = go.Scatter(x = data['Rank'], y = data['Population'] + i * 1e6, mode = 'markers', marker = dict(size = 14, line = dict(width = 1), color = c[i], opacity = 0.3), name = data['State'])
  l.append(trace0)
layout = go.Layout(title = 'Población de los estados de USA', hovermode = 'closest', xaxis = dict(title = 'ID', ticklen = 5, zeroline = False, gridwidth = 2), yaxis = dict(title = 'Población', ticklen = 5, gridwidth = 2), showlegend = False)
fig = go.Figure(data = l, layout = layout)
py.plot(fig)
# Out:
# 'https://chart-studio.plotly.com/~javilledo/82'

# %%
trace = go.Scatter(y = np.random.randn(1000), mode = 'markers', marker = dict(size = 16, color = np.random.randn(1000), colorscale = 'Viridis', showscale = True))
fig = go.Figure(data = [trace], layout = layout)
py.plot(fig)
# Out:
# 'https://chart-studio.plotly.com/~javilledo/84'

# %% [markdown]
# #Datasets muy grandes

# %%
N = 100000
trace = go.Scattergl(x = np.random.randn(N), y = np.random.randn(N), mode = 'markers', marker = dict(color = '#BAD5FF', line = dict(width = 1)))
py.plot([trace])
# Out:
# 'https://chart-studio.plotly.com/~javilledo/86'
