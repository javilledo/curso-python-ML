# %% [markdown]
# **LIBRERÍAS**
# * pandas
# * numpy
# * matplotlib
# * ipython
# * scikit-learn
#
# comunidad pydata.org

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk

# %% [markdown]
# **ETAPAS DEL ANÁLISIS DE DATOS**
# * Determinación del **problema** a resolver
# * **Adquirir** y preparar los datos
# * **Explorar** los datos
# * **Modelizar** y evaluar los datos
# * **Comunicar** los resultados y/o puesta en **producción**

# %% [markdown]
# **CAMBIOS A PARTIR DE PYTHON 3.7**
#
# *from sklearn.model_selection import GridSearchCV* en lugar de *sklearn.grid_search*
#
# *from sklearn.model_selection import xxx* en lugar de *import sklearn.xxx*
#
# función train_test_split desde *sklearn.model_selection* en lugar de desde *sklearn.cross_validation*
#
# *np.nan* en lugar de *NaN*
